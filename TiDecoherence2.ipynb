# %%
# !pip install pycce
# !pip install ase
# Out:
# Requirement already satisfied: pycce in ./opt/anaconda3/lib/python3.9/site-packages (1.0.1.3)
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.9/site-packages (from pycce) (1.3.4)
# Requirement already satisfied: scipy in ./opt/anaconda3/lib/python3.9/site-packages (from pycce) (1.7.1)
# Requirement already satisfied: ase in ./opt/anaconda3/lib/python3.9/site-packages (from pycce) (3.22.1)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from pycce) (1.20.3)
# Requirement already satisfied: matplotlib>=3.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ase->pycce) (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->pycce) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->pycce) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->pycce) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->pycce) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase->pycce) (2.8.2)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.1.0->ase->pycce) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas->pycce) (2021.3)
# Requirement already satisfied: ase in ./opt/anaconda3/lib/python3.9/site-packages (3.22.1)
# Requirement already satisfied: matplotlib>=3.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ase) (3.4.3)
# Requirement already satisfied: scipy>=1.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ase) (1.7.1)
# Requirement already satisfied: numpy>=1.15.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ase) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.0->ase) (2.8.2)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.1.0->ase) (1.16.0)

# %% [markdown]
# Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
import pycce as pc
import ase
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Setting up simulator object

# %% [markdown]
# Import the .xyz file

# %%
filename="ti.xyz"
xyz = open(filename)
#print(xyz.read()) #prints the hole file
n_atoms = int(xyz.readline())
#print(n_atoms) #number of atoms 
title = xyz.readline()
#print(title)
atoms=xyz

# %% [markdown]
# <span style='background:yellow'> _Coments for Valerio_:  This is what we did on Tuesday :)
#   </span>

# %% [markdown]
# Initialization of the Simulator

# %%
calc = pc.Simulator(1, position=[0,0,0], bath=atoms, r_bath=40, r_dipole=6, order=2, magnetic_field=500, pulses=1)
print(calc)
# Out:
# Simulator for center array of size 1.
# magnetic field:
# array([  0.,   0., 500.])
#
# Parameters of cluster expansion:
# r_bath: 40
# r_dipole: 6
# order: 2
#
# Bath consists of 107 spins.
#
# Clusters include:
# 107  clusters of order 1.
# 2228  clusters of order 2.

# %%
filename="ti.xyz"
xyz = open(filename)
#print(xyz.read()) #prints the hole file
n_atoms = int(xyz.readline())
#print(n_atoms) #number of atoms 
title = xyz.readline()
#print(title)
atoms=xyz

xh=[]
yh=[]
zh=[]
xt=[]
yt=[]
zt=[]
xc=[]
yc=[]
zc=[]
for line in xyz:
    
    atom, x,y,z = line.split()
    #Ti atoms
    if atom == 'Ti':
        xt.append(float(x))
        yt.append(float(y))
        zt.append(float(z))
    #Carbon atoms
    elif atom=='C':
        xc.append(float(x))
        yc.append(float(y))
        zc.append(float(z))
    #Hydrogen atoms
    else:
        xh.append(float(x))
        yh.append(float(y))
        zh.append(float(z))
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter3D(xt,yt,zt, c='r', marker='o', label='Ti')
ax.scatter3D(xc,yc,zc, c='b', marker='o', label='C')
ax.scatter3D(xh,yh,zh, c='green', marker='o', label='H')
ax.legend()
ax.set_xlabel('X (A)')
ax.set_ylabel('Y (A)')
ax.set_zlabel('Z (A)')

plt.title("CpTi[cot] unit cell", fontsize = 14) 

plt.show()

# %% [markdown]
# ### Positions of the spins in the bath

# %% [markdown]
# Define the Simulator as a Class

# %%
class Simulator:
    def __init__(spin, bath, r_bath, r_dipole, magnetic_field, order):
        spin.bath=bath
        spin.r_bath=r_bath
        spin.r_dipole = r_dipole
        spin.magnetic_field=magnetic_field
        spin.order=order
s1=Simulator(atoms, 40, 6, 500, 2)
print()
print("r_bath: ", s1.r_bath)
print("r_dipole: ", s1.r_dipole)
print("magnetic field: ", s1.magnetic_field)
print("order: ",s1.order)
# Out:
# r_bath:  40
# r_dipole:  6
# magnetic field:  500
# order:  2

# %% [markdown]
# <span style='background:yellow'> _Coments for Valerio_:  This is just me defining the simulator as a class in case I need it in the future but I don't think it has that much relevance at the moment.
#   </span>

# %% [markdown]
# ### Compute coherence function with conventional CCE

# %%
time_steps = np.linspace(0, 2, 101) #time points in ms at which the coherence function is computed
n=1 #pulses in Carr-Purcell-Meiboom-Gill (CPMG) sequence 
b=np.array([0,0,0]) #magnetic field along the z-axis Default=[0,0,0]

#use coherence function with conventional CCE
l_conv = calc.compute(time_steps, pulses=n, magnetic_field=b, method='cce', quantity='coherence', as_delay=False)

# %%
calc = pc.Simulator(spin=0.5, position=[0,0,0], bath=atoms, r_bath=40, magnetic_field=[0,0,0], pulses=1, r_dipole=6, order=2)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /var/folders/07/02v51ss15857xv4ddkzq17_c0000gn/T/ipykernel_12055/1344807647.py in <module>
# ----> 1 calc = pc.Simulator(spin=0.5, position=[0,0,0], bath=atoms, r_bath=40, magnetic_field=[0,0,0], pulses=1, r_dipole=6, order=2)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycce/main.py in __init__(self, spin, position, alpha, beta, gyro, magnetic_field, D, E, r_dipole, order, bath, pulses, as_delay, n_clusters, **bath_kw)
#     427         self._error_range = 0.2
#     428
# --> 429         self.read_bath(bath=bath, **bath_kw)
#     430
#     431         # Parameters of the calculations
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycce/main.py in read_bath(self, bath, r_bath, skiprows, external_bath, hyperfine, types, error_range, ext_r_bath, imap, func_kw)
#     933
#     934         if bath is not None:
# --> 935             self.total_bath = read_xyz(bath, skiprows=skiprows, spin_types=types, imap=imap)
#     936
#     937         bath = self.total_bath
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycce/io/xyz.py in read_xyz(xyz, skiprows, spin_types, isotopes, imap)
#      59     else:
#      60         dt_read = np.dtype([('N', np.unicode_, 16), ('xyz', np.float64, (3,))])
# ---> 61         dataset = np.loadtxt(xyz, dtype=dt_read, skiprows=skiprows)
#      62
#      63     with warnings.catch_warnings(record=True) as w:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1087         # Skip the first `skiprows` lines
#    1088         for i in range(skiprows):
# -> 1089             next(fh)
#    1090
#    1091         # Read until we find a line with some values, and use
#
# StopIteration:

# %% [markdown]
# __as_delay__: True only if the points are delay between pulses, False if the time points are total time. Ignored if 'pulses' contains the time delays. _Type: Bool_

# %% [markdown]
# Define the time steps and calculate the coherence in those time steps

# %%
# parameters of calcuations
parameters = dict(
    order=2, # CCE order
    r_bath=40,  # Size of the bath in A
    r_dipole=6,  # Cutoff of pairwise clusters in A
    position=[0, 0, 0], # Position of central Spin
    pulses = 1, # N pulses in CPMG sequence
    magnetic_field=[0,0,0]
    
) 
time_space = time_steps

# %%
calc = pc.Simulator(spin=1, bath=atoms, **parameters)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /var/folders/07/02v51ss15857xv4ddkzq17_c0000gn/T/ipykernel_12055/3049267294.py in <module>
# ----> 1 calc = pc.Simulator(spin=1, bath=atoms, **parameters)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycce/main.py in __init__(self, spin, position, alpha, beta, gyro, magnetic_field, D, E, r_dipole, order, bath, pulses, as_delay, n_clusters, **bath_kw)
#     427         self._error_range = 0.2
#     428
# --> 429         self.read_bath(bath=bath, **bath_kw)
#     430
#     431         # Parameters of the calculations
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycce/main.py in read_bath(self, bath, r_bath, skiprows, external_bath, hyperfine, types, error_range, ext_r_bath, imap, func_kw)
#     933
#     934         if bath is not None:
# --> 935             self.total_bath = read_xyz(bath, skiprows=skiprows, spin_types=types, imap=imap)
#     936
#     937         bath = self.total_bath
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pycce/io/xyz.py in read_xyz(xyz, skiprows, spin_types, isotopes, imap)
#      59     else:
#      60         dt_read = np.dtype([('N', np.unicode_, 16), ('xyz', np.float64, (3,))])
# ---> 61         dataset = np.loadtxt(xyz, dtype=dt_read, skiprows=skiprows)
#      62
#      63     with warnings.catch_warnings(record=True) as w:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1087         # Skip the first `skiprows` lines
#    1088         for i in range(skiprows):
# -> 1089             next(fh)
#    1090
#    1091         # Read until we find a line with some values, and use
#
# StopIteration:
